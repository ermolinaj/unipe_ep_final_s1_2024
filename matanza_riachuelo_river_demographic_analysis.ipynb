# %%
import pandas as pd

# %% [markdown]
# Importación de los datasets de Acumar:

# %%
tons_of_waste_15 = pd.read_csv("datasets/water_mirror_cleaning/toneladas_retiradas_espejo_2015_2019.csv", sep=';', encoding='latin1')

tons_of_waste_15
# Out:
#     mes_inicio mes_finalizacion  toneladas_retiradas   año
# 0        ENERO          FEBRERO               355.38  2015
# 1      FEBRERO            MARZO               263.73  2015
# 2        MARZO            ABRIL               248.39  2015
# 3        ABRIL             MAYO               346.43  2015
# 4         MAYO            JUNIO               250.27  2015
# 5        JUNIO            JULIO               317.12  2015
# 6        JULIO           AGOSTO               414.88  2015
# 7       AGOSTO       SEPTIEMBRE               218.70  2015
# 8   SEPTIEMBRE          OCTUBRE               314.92  2015
# 9      OCTUBRE        NOVIEMBRE               533.54  2015
# 10   NOVIEMBRE        DICIEMBRE               260.86  2015
# 11   DICIEMBRE            ENERO               501.55  2015
# 12       ENERO          FEBRERO               525.60  2016
# 13     FEBRERO            MARZO               415.92  2016
# 14       MARZO            ABRIL               412.18  2016
# ...

# %%
tons_of_waste_19 = pd.read_csv("datasets/water_mirror_cleaning/toneladas_retiradas_espejo_2019_2020.csv", sep=';', encoding='latin1')

tons_of_waste_19
# Out:
#                                     espejo de agua,,,
# 0   mes_inicio,mes_finalizacion,toneladas_retirada...
# 1                       OCTUBRE,NOVIEMBRE,300.78,2019
# 2                     NOVIEMBRE,DICIEMBRE,349.86,2019
# 3                         DICIEMBRE,ENERO,391.94,2020
# 4                           ENERO,FEBRERO,345.88,2020
# 5                           FEBRERO,MARZO,251.62,2020
# 6                             MARZO,ABRIL,220.62,2020
# 7                              ABRIL,MAYO,329.04,2020
# 8                              MAYO,JUNIO,277.74,2020
# 9                             JUNIO,JULIO,362.36,2020
# 10                           JULIO,AGOSTO,157.84,2020
# 11                      AGOSTO,SEPTIEMBRE,303.44,2020
# 12                     SEPTIEMBRE,OCTUBRE,234.42,2020
# 13                      OCTUBRE,NOVIEMBRE,260.78,2020
# 14                    NOVIEMBRE,DICIEMBRE,321.54,2020

# %%
tons_of_waste_20 = pd.read_csv("datasets/water_mirror_cleaning/toneladas_retiradas_espejo_2020_2021.csv", sep=';', encoding='latin1')

tons_of_waste_20
# Out:
#    mes_inicio,mes_finalizacion,toneladas_retiradas,anio
# 0                         DICIEMBRE,ENERO,248.54,2020
# 1                           ENERO,FEBRERO,144.28,2021
# 2                           FEBRERO,MARZO,303.62,2021
# 3                              MARZO,ABRIL,418.8,2021
# 4                              ABRIL,MAYO,414.66,2021
# 5                              MAYO,JUNIO,356.54,2021
# 6                             JUNIO,JULIO,334.18,2021
# 7                            JULIO,AGOSTO,351.46,2021
# 8                      SEPTIEMBRE,SEPTIEMBRE,616,2021
# 9                         OCTUBRE,OCTUBRE,331.42,2021
# 10                    NOVIEMBRE,NOVIEMBRE,271.31,2021
# 11                    DICIEMBRE,DICIEMBRE,315.96,2021

# %%
tons_of_waste_22 = pd.read_csv("datasets/water_mirror_cleaning/toneladas_retiradas_espejo_2019_2020.csv", sep=';', encoding='latin1')

tons_of_waste_22
# Out:
#                                     espejo de agua,,,
# 0   mes_inicio,mes_finalizacion,toneladas_retirada...
# 1                       OCTUBRE,NOVIEMBRE,300.78,2019
# 2                     NOVIEMBRE,DICIEMBRE,349.86,2019
# 3                         DICIEMBRE,ENERO,391.94,2020
# 4                           ENERO,FEBRERO,345.88,2020
# 5                           FEBRERO,MARZO,251.62,2020
# 6                             MARZO,ABRIL,220.62,2020
# 7                              ABRIL,MAYO,329.04,2020
# 8                              MAYO,JUNIO,277.74,2020
# 9                             JUNIO,JULIO,362.36,2020
# 10                           JULIO,AGOSTO,157.84,2020
# 11                      AGOSTO,SEPTIEMBRE,303.44,2020
# 12                     SEPTIEMBRE,OCTUBRE,234.42,2020
# 13                      OCTUBRE,NOVIEMBRE,260.78,2020
# 14                    NOVIEMBRE,DICIEMBRE,321.54,2020

# %%
tons_of_waste_23 = pd.read_csv("datasets/water_mirror_cleaning/toneladas_retiradas_espejo_2019_2020.csv", sep=';', encoding='latin1')

tons_of_waste_23
# Out:
#                                     espejo de agua,,,
# 0   mes_inicio,mes_finalizacion,toneladas_retirada...
# 1                       OCTUBRE,NOVIEMBRE,300.78,2019
# 2                     NOVIEMBRE,DICIEMBRE,349.86,2019
# 3                         DICIEMBRE,ENERO,391.94,2020
# 4                           ENERO,FEBRERO,345.88,2020
# 5                           FEBRERO,MARZO,251.62,2020
# 6                             MARZO,ABRIL,220.62,2020
# 7                              ABRIL,MAYO,329.04,2020
# 8                              MAYO,JUNIO,277.74,2020
# 9                             JUNIO,JULIO,362.36,2020
# 10                           JULIO,AGOSTO,157.84,2020
# 11                      AGOSTO,SEPTIEMBRE,303.44,2020
# 12                     SEPTIEMBRE,OCTUBRE,234.42,2020
# 13                      OCTUBRE,NOVIEMBRE,260.78,2020
# 14                    NOVIEMBRE,DICIEMBRE,321.54,2020
